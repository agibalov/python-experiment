# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.title('Hurray!')
plt.plot([5, 2, 5])
plt.show()

# %%
def get_some_library_data():
    return 123

# %%
if __name__ == '__main__' and '__file__' not in globals():
    print("I'm not a library at the moment")
# Out:
# I'm not a library at the moment
