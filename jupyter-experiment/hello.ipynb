# %% [markdown]
# # hello world!

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## hello numpy

# %%
import numpy as np
print(np.array([11, 22, 33]) / 5)
# Out:
# [2.2 4.4 6.6]

# %% [markdown]
# ## hello pyplot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot([10, 2, 7, 8, 3])
plt.ylabel('some numbers')
plt.xlabel('some other numbers')
plt.show()

# %%
# %run library.ipynb

# %%
data = get_some_library_data()
data
# Out:
# 123
